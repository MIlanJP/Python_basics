# %%
import pandas as pd

# %%
number_series=pd.Series([10,200,16,4,8,4621,4])
print(number_series,type(number_series))
# Out:
# 0      10
# 1     200
# 2      16
# 3       4
# 4       8
# 5    4621
# 6       4
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
number_series=pd.Series([2,5,6,9,4,2,],index=["a","b","c","d","e","f"])
number_series=pd.DataFrame(number_series)
number_series
# Out:
#    0
# a  2
# b  5
# c  6
# d  9
# e  4
# f  2

# %%
n1=pd.Series([2,6,7,2,1,5],index=["a","b","c","i","h","g"])
n1=pd.DataFrame(n1)
n1
# Out:
#    0
# a  2
# b  6
# c  7
# i  2
# h  1
# g  5

# %%
n1+number_series
pd.merge(n1,number_series,how="outer",left_index=True,right_index=True)
# Out:
#    0_x  0_y
# a  2.0  2.0
# b  6.0  5.0
# c  7.0  6.0
# d  NaN  9.0
# e  NaN  4.0
# f  NaN  2.0
# g  5.0  NaN
# h  1.0  NaN
# i  2.0  NaN

# %%
pd.concat(number_series,n1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-4542f21e92ef> in <module>
# ----> 1 pd.concat(number_series,n1)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     318     ):
#     319         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
# --> 320             raise TypeError(
#     321                 "first argument must be an iterable of pandas "
# ...

# %%
import numpy as np
some2d=np.random.randint(4,6,(3,4))
df=pd.DataFrame(some2d,columns=["Nasta","Ota","Snacks","Tindi"])
df
# Out:
#    Nasta  Ota  Snacks  Tindi
# 0      5    4       4      5
# 1      4    5       4      4
# 2      4    5       4      4

# %%
df2=pd.DataFrame(some2d,columns=["Nasta","Ota","Snacks","Tindi"],index=["A","B","C"])

# %%
df2
# Out:
#    Nasta  Ota  Snacks  Tindi
# A      5    4       4      5
# B      4    5       4      4
# C      4    5       4      4

# %%
import pandas as pd
# Creaitng data frame using list of lists
lol=[["Amar",10],["Akbar",20],["Anthony",14]]
df=pd.DataFrame(lol,columns=["Name","Age"])
df
# Out:
#       Name  Age
# 0     Amar   10
# 1    Akbar   20
# 2  Anthony   14

# %%
# Creating data frame from dictionary
employee_dict={"Employee_Name":["Rajeev","Mishra","Aravali"],"Income":[120000,1600000,1000000]}
df3=pd.DataFrame(employee_dict)

# %%
df3
# Out:
#   Employee_Name   Income
# 0        Rajeev   120000
# 1        Mishra  1600000
# 2       Aravali  1000000

# %%
di=[{"A":1,"B":2,"C":3},{"A":67,"B":456,"C":78}]
df=pd.DataFrame(di)
df
# Out:
#     A    B   C
# 0   1    2   3
# 1  67  456  78

# %% [markdown]
# # Data wrangling

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./Python basics/Datasets/imdb_data.csv")
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
# Droping the column ID
df.drop('id',axis=1,inplace=True)

# %%
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df
# Out:
#                                   belongs_to_collection    budget  \
# 0     [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                   NaN   3300000
# 3                                                   NaN   1200000
# 4                                                   NaN         0
# ...                                                 ...       ...
# 2995                                                NaN         0
# 2996                                                NaN         0
# 2997                                                NaN  65000000
# 2998                                                NaN  42000000
# 2999                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
# Create three data frames
df1=df[df["runtime"]>=150]
df2=df[(df["runtime"]<150) & (df["runtime"] > 100)]
df3=df[df["runtime"] < 100]

# %%
df1.head()
# Out:
#     belongs_to_collection    budget  \
# 47                    NaN  44000000
# 51                    NaN  12000000
# 76                    NaN    500000
# 97                    NaN         0
# 107                   NaN  72000000
#
#                                                 genres  \
# 47   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97   [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                         homepage    imdb_id original_language  \
# 47   http://thehatefuleight.com/  tt3460252                en
# 51                           NaN  tt0059243                en
# 76                           NaN  tt0242572                ta
# 97                           NaN  tt1772980                ru
# 107                          NaN  tt0112573                en
#
# ...

# %%
df2.head()
# Out:
#                                 belongs_to_collection    budget  \
# 1   [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                 NaN   3300000
# 3                                                 NaN   1200000
# 4                                                 NaN         0
# 10  [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
#
#                                                genres  \
# 1   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                       [{'id': 18, 'name': 'Drama'}]
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 10                      [{'id': 18, 'name': 'Drama'}]
#
#                              homepage    imdb_id original_language  \
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# ...

# %%
df3.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 5                                                NaN   8000000
# 6                                                NaN  14000000
# 7                                                NaN         0
# 9                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7                [{'id': 99, 'name': 'Documentary'}]
# 9  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 5                                 NaN  tt0093743                en
# ...

# %%
# Create three data frames
df6=df.loc[df["runtime"]>=150]
df5=df.loc[(df["runtime"]<150) & (df["runtime"] > 100)]
df4=df.loc[df["runtime"] < 100]

# %%
df6.head()
# Out:
#     belongs_to_collection    budget  \
# 47                    NaN  44000000
# 51                    NaN  12000000
# 76                    NaN    500000
# 97                    NaN         0
# 107                   NaN  72000000
#
#                                                 genres  \
# 47   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97   [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                         homepage    imdb_id original_language  \
# 47   http://thehatefuleight.com/  tt3460252                en
# 51                           NaN  tt0059243                en
# 76                           NaN  tt0242572                ta
# 97                           NaN  tt1772980                ru
# 107                          NaN  tt0112573                en
#
# ...

# %%
df5.head()
# Out:
#                                 belongs_to_collection    budget  \
# 1   [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                 NaN   3300000
# 3                                                 NaN   1200000
# 4                                                 NaN         0
# 10  [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
#
#                                                genres  \
# 1   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                       [{'id': 18, 'name': 'Drama'}]
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 10                      [{'id': 18, 'name': 'Drama'}]
#
#                              homepage    imdb_id original_language  \
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# ...

# %%
df4.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 5                                                NaN   8000000
# 6                                                NaN  14000000
# 7                                                NaN         0
# 9                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7                [{'id': 99, 'name': 'Documentary'}]
# 9  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 5                                 NaN  tt0093743                en
# ...

# %%
# First import merge operations is concat operation
pd.concat([df1,df2,df3],axis=0)
# Out:
#      belongs_to_collection    budget  \
# 47                     NaN  44000000
# 51                     NaN  12000000
# 76                     NaN    500000
# 97                     NaN         0
# 107                    NaN  72000000
# ...                    ...       ...
# 2987                   NaN         0
# 2988                   NaN         0
# 2989                   NaN         0
# 2990                   NaN         0
# 2998                   NaN  42000000
#
#                                                  genres  \
# 47    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51    [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97    [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# ...                                                 ...
# 2987  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2988                      [{'id': 18, 'name': 'Drama'}]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  604 non-null    object
#  1   budget                 3000 non-null   int64
#  2   genres                 2993 non-null   object
#  3   homepage               946 non-null    object
#  4   imdb_id                3000 non-null   object
#  5   original_language      3000 non-null   object
#  6   original_title         3000 non-null   object
#  7   overview               2992 non-null   object
#  8   popularity             3000 non-null   float64
#  9   poster_path            2999 non-null   object
#  10  production_companies   2844 non-null   object
#  11  production_countries   2945 non-null   object
#  12  release_date           3000 non-null   object
#  13  runtime                2998 non-null   float64
# ...

# %%
# Group by operations
from datetime import datetime
from datetime import date

# %%
english_movies=df.loc[df["original_language"]=="en"]

# %%
longest_movies=df.loc[df["runtime"]>100,["imdb_id","original_language"]]
longest_movies
# Out:
#         imdb_id original_language
# 1     tt0368933                en
# 2     tt2582802                en
# 3     tt1821480                hi
# 4     tt1380152                ko
# 10    tt0075148                en
# ...         ...               ...
# 2994  tt0105327                en
# 2995  tt0109403                en
# 2996  tt2364975                sv
# 2997  tt0116908                en
# 2999  tt1600195                en
#
# [1721 rows x 2 columns]

# %%
df["runtime"].mean()
# Out:
# 107.85657104736491

# %%
df["runtime"].sum()
# Out:
# 323354.0

# %%
df["new_release_date1"]=df["release_date"].apply(lambda x :datetime.strptime(x,"%m/%d/%y"))

# %%
df
# Out:
#                                   belongs_to_collection    budget  \
# 0     [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                   NaN   3300000
# 3                                                   NaN   1200000
# 4                                                   NaN         0
# ...                                                 ...       ...
# 2995                                                NaN         0
# 2996                                                NaN         0
# 2997                                                NaN  65000000
# 2998                                                NaN  42000000
# 2999                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
df["new_release_date"]
# Out:
# 0      2015-02-20
# 1      2004-08-06
# 2      2014-10-10
# 3      2012-03-09
# 4      2009-02-05
#           ...
# 2995   1994-04-22
# 2996   2013-03-28
# 2997   1996-10-11
# 2998   2004-01-16
# 2999   2011-09-22
# Name: new_release_date, Length: 3000, dtype: datetime64[ns]

# %%
df=pd.read_csv("./Python basics/Datasets/imdb_data.csv")

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df["genres"]
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 3000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
import json
df1=pd.DataFrame()

for i,x in enumerate(df["genres"]):
    if (not isinstance(x,str)):continue
    updated_word=""
    for j in x.split("}"):
        if "]" in j:
            updated_word=updated_word+"]"
        else:
            updated_word=updated_word+j+',\'imdb_id'+ '\':\''+str(df.loc[i,"imdb_id"])+'\'}'

    df1=pd.concat([df1,pd.DataFrame(json.loads(updated_word.replace("\'",'\"')))])
# Out:
# [{'id': 35, 'name': 'Comedy','imdb_id':'tt2637294'}]
# [{'id': 35, 'name': 'Comedy','imdb_id':'tt0368933'}, {'id': 18, 'name': 'Drama','imdb_id':'tt0368933'}, {'id': 10751, 'name': 'Family','imdb_id':'tt0368933'}, {'id': 10749, 'name': 'Romance','imdb_id':'tt0368933'}]
# [{'id': 18, 'name': 'Drama','imdb_id':'tt2582802'}]
# [{'id': 53, 'name': 'Thriller','imdb_id':'tt1821480'}, {'id': 18, 'name': 'Drama','imdb_id':'tt1821480'}]
# [{'id': 28, 'name': 'Action','imdb_id':'tt1380152'}, {'id': 53, 'name': 'Thriller','imdb_id':'tt1380152'}]
# [{'id': 16, 'name': 'Animation','imdb_id':'tt0093743'}, {'id': 12, 'name': 'Adventure','imdb_id':'tt0093743'}, {'id': 10751, 'name': 'Family','imdb_id':'tt0093743'}]
# [{'id': 27, 'name': 'Horror','imdb_id':'tt0431021'}, {'id': 53, 'name': 'Thriller','imdb_id':'tt0431021'}]
# [{'id': 99, 'name': 'Documentary','imdb_id':'tt0391024'}]
# ...

# %%
len("{'id': 35, 'name': 'Comedy','imdb_id' : 'tt2637294',}")
# Out:
# 53

# %%
df1
# Out:
#        id      name    imdb_id
# 0      35    Comedy  tt2637294
# 0      35    Comedy  tt0368933
# 1      18     Drama  tt0368933
# 2   10751    Family  tt0368933
# 3   10749   Romance  tt0368933
# ..    ...       ...        ...
# 0      35    Comedy  tt0343135
# 1   10749   Romance  tt0343135
# 0      53  Thriller  tt1600195
# 1      28    Action  tt1600195
# 2    9648   Mystery  tt1600195
#
# [7511 rows x 3 columns]

# %%
df1.name.unique()
# Out:
# array(['Comedy', 'Drama', 'Family', 'Romance', 'Thriller', 'Action',
#        'Animation', 'Adventure', 'Horror', 'Documentary', 'Music',
#        'Crime', 'Science Fiction', 'Mystery', 'Foreign', 'Fantasy', 'War',
#        'Western', 'History', 'TV Movie'], dtype=object)
