# %% [markdown]
# https://www.youtube.com/watch?v=hl-TGI4550M&list=PL5-da3qGB5IBITZj_dYSFqnd_15JgqwA6
#
# kevin markam

# %% [markdown]
# # 1. Show installed versions

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 2cb96529396d93b46abab7bbc73a208e708c642e
# python           : 3.8.8.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.19041
# machine          : AMD64
# processor        : Intel64 Family 6 Model 61 Stepping 4, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_India.1252
#
# pandas           : 1.2.4
# numpy            : 1.20.1
# pytz             : 2021.1
# dateutil         : 2.8.1
# pip              : 21.0.1
# setuptools       : 52.0.0.post20210125
# Cython           : 0.29.23
# pytest           : 6.2.3
# hypothesis       : None
# sphinx           : 4.0.1
# blosc            : None
# feather          : None
# xlsxwriter       : 1.3.8
# lxml.etree       : 4.6.3
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.3
# IPython          : 7.22.0
# ...

# %% [markdown]
# # How do I read a tabular data file into pandas ?

# %%
import pandas as pd

# %%
# df= pd.read('http://bit.ly/chiporders')

# %%
# df.to_csv("./Datasets/Chiporders.csv")

# %%
# pd.read_table('http://bit.ly/chiporders')

# %%
df=pd.read_csv('./Datasets/Chiporders.csv')

# %%
# df1=pd.read_table("http://bit.ly/movieusers",delimiter="|")

# %%
df
# Out:
#       Unnamed: 0  order_id  quantity                              item_name  \
# 0              0         1         1           Chips and Fresh Tomato Salsa
# 1              1         1         1                                   Izze
# 2              2         1         1                       Nantucket Nectar
# 3              3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4              4         2         2                           Chicken Bowl
# ...          ...       ...       ...                                    ...
# 4617        4617      1833         1                          Steak Burrito
# 4618        4618      1833         1                          Steak Burrito
# 4619        4619      1834         1                     Chicken Salad Bowl
# 4620        4620      1834         1                     Chicken Salad Bowl
# 4621        4621      1834         1                     Chicken Salad Bowl
#
# ...

# %%
# df1.to_csv("./Datasets/MovieUsers.csv")

# %%
# Giving header as None because if you dont use that first value of row will occupy the column names place
df1=pd.read_csv("./Datasets/MovieUsers.csv",header=None)

# %%
df1
# Out:
#          0    1   2  3              4      5
# 0      NaN    1  24  M     technician  85711
# 1      0.0    2  53  F          other  94043
# 2      1.0    3  23  M         writer  32067
# 3      2.0    4  24  M     technician  43537
# 4      3.0    5  33  F          other  15213
# ..     ...  ...  .. ..            ...    ...
# 938  937.0  939  26  F        student  33319
# 939  938.0  940  32  M  administrator  02215
# 940  939.0  941  20  M        student  97229
# 941  940.0  942  48  F      librarian  78209
# 942  941.0  943  22  M        student  77841
#
# [943 rows x 6 columns]

# %%
# This below line is used for deleting a column 
df1.drop(df1.columns[0],axis=1,inplace=True)

# %%
# df=df.iloc[:10,:]
df1
# Out:
#        1   2  3              4      5
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
# Renaming columns
#  Storing the columns name in a list and passing as names while importing file
user_cols=["user_id","age","gender","occupation","zipcode"]
df2=pd.read_csv("./Datasets/MovieUsers.csv",header=None,names=user_cols)
df2
# Out:
#        user_id  age gender     occupation zipcode
# NaN          1   24      M     technician   85711
# 0.0          2   53      F          other   94043
# 1.0          3   23      M         writer   32067
# 2.0          4   24      M     technician   43537
# 3.0          5   33      F          other   15213
# ...        ...  ...    ...            ...     ...
# 937.0      939   26      F        student   33319
# 938.0      940   32      M  administrator   02215
# 939.0      941   20      M        student   97229
# 940.0      942   48      F      librarian   78209
# 941.0      943   22      M        student   77841
#
# [943 rows x 5 columns]

# %%
user_cols=["user_id","age","gender","occupation","zipcode"]
df1.columns=user_cols
df1
# Out:
#      user_id  age gender     occupation zipcode
# 0          1   24      M     technician   85711
# 1          2   53      F          other   94043
# 2          3   23      M         writer   32067
# 3          4   24      M     technician   43537
# 4          5   33      F          other   15213
# ..       ...  ...    ...            ...     ...
# 938      939   26      F        student   33319
# 939      940   32      M  administrator   02215
# 940      941   20      M        student   97229
# 941      942   48      F      librarian   78209
# 942      943   22      M        student   77841
#
# [943 rows x 5 columns]

# %%
df1.head()
# Out:
#    user_id  age gender  occupation zipcode
# 0        1   24      M  technician   85711
# 1        2   53      F       other   94043
# 2        3   23      M      writer   32067
# 3        4   24      M  technician   43537
# 4        5   33      F       other   15213

# %% [markdown]
# # Bonus TIP 1
# In pd.read_table
# 1. skip rows
# 2. skip footer

# %% [markdown]
# # How do i select a pandas Series from a Data frame ?

# %%
import pandas as pd

# %%
# ufo=pd.read_csv("http://bit.ly/uforeports")
# read csv uses comma as default delimiter
# read table uses tab space as default delimiter

# %%
# ufo.to_csv("./Datasets/uforeports.csv")

# %%
ufo=pd.read_csv("./Datasets/uforeports.csv")
ufo.drop(ufo.columns[0],axis=1,inplace=True)
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.City.head()
# Out:
# 0                  Ithaca
# 1             Willingboro
# 2                 Holyoke
# 3                 Abilene
# 4    New York Worlds Fair
# Name: City, dtype: object

# %%
ufo["Colors Reported"].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Colors Reported, dtype: object

# %%
# Columns can be used using dot notations
# If the column name has space between you cant access columns using dot notations
#

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# So how to create a data frame using pandas in python

# While assgin a value to column u have to use the column names with in the square brackets
ufo["Location"]=ufo.City+", "+ufo.State

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %% [markdown]
# # Why do some pandas commands ends with parenthesis and other commands dont

# %%
import pandas as pd

# %%
# movies=pd.read_csv("http://bit.ly/imdbratings")
# movies.to_csv("./Datasets/imdbratings.csv")

# %%
movies=pd.read_csv("./Datasets/imdbratings.csv")
movies.head()
# Out:
#    Unnamed: 0  star_rating                     title content_rating   genre  \
# 0           0          9.3  The Shawshank Redemption              R   Crime
# 1           1          9.2             The Godfather              R   Crime
# 2           2          9.1    The Godfather: Part II              R   Crime
# 3           3          9.0           The Dark Knight          PG-13  Action
# 4           4          8.9              Pulp Fiction              R   Crime
#
#    duration                                        actors_list
# 0       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.drop(movies.columns[0],axis=1,inplace=True)

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
    movies.shape
# Out:
# (979, 6)

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
type(movies.duration)
# Out:
# pandas.core.series.Series

# %%
movies.describe(include=["object"])
# Out:
#           title content_rating  genre  \
# count       979            976    979
# unique      975             12     16
# top     Dracula              R  Drama
# freq          2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %% [markdown]
# # Bonus tip
#
# Shift Tab is very useful to get to know about the method

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
ufo.rename(columns={"Colors Reported":"Colors_Reported","Shape Reported":"Shape_Reported"},inplace=True)
ufo.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
ufo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
ufo_cols=['City', 'Colors_a_Reported', 'Shape_a_Reported', 'State', 'Time','Location']
ufo.columns=ufo_cols

# %%
ufo.head()
# Out:
#                    City Colors_a_Reported Shape_a_Reported State  \
# 0                Ithaca               NaN         TRIANGLE    NY
# 1           Willingboro               NaN            OTHER    NJ
# 2               Holyoke               NaN             OVAL    CO
# 3               Abilene               NaN             DISK    KS
# 4  New York Worlds Fair               NaN            LIGHT    NY
#
#               Time                  Location
# 0   6/1/1930 22:00                Ithaca, NY
# 1  6/30/1930 20:00           Willingboro, NJ
# 2  2/15/1931 14:00               Holyoke, CO
# 3   6/1/1931 13:00               Abilene, KS
# 4  4/18/1933 19:00  New York Worlds Fair, NY

# %%
ufo1=pd.read_csv("./Datasets/uforeports.csv",names=ufo_cols,header=0)

# %%
ufo1.head()
# Out:
#    City     Colors_a_Reported Shape_a_Reported     State Time         Location
# 0     0                Ithaca              NaN  TRIANGLE   NY   6/1/1930 22:00
# 1     1           Willingboro              NaN     OTHER   NJ  6/30/1930 20:00
# 2     2               Holyoke              NaN      OVAL   CO  2/15/1931 14:00
# 3     3               Abilene              NaN      DISK   KS   6/1/1931 13:00
# 4     4  New York Worlds Fair              NaN     LIGHT   NY  4/18/1933 19:00

# %%
ufo2=pd.read_csv("./Datasets/uforeports.csv",header=0)
ufo2.drop(ufo2.columns[0],inplace=True,axis=1)

# %%
ufo2.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo2.columns=ufo2.columns.str.replace(" ","_")
ufo2.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time'], dtype='object')

# %%
ufo2.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# # How do I remove column from a Data Frame

# %%
ufo=pd.read_csv("./Datasets/uforeports.csv")

# %%
ufo.head()
# Out:
#    Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#               Time
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00
# 2  2/15/1931 14:00
# 3   6/1/1931 13:00
# 4  4/18/1933 19:00

# %%
ufo.drop("Colors Reported",axis=1,inplace=True)

# %%
ufo.head()
# Out:
#    Unnamed: 0                  City Shape Reported State             Time
# 0           0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2           2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3           3               Abilene           DISK    KS   6/1/1931 13:00
# 4           4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
ufo=pd.read_csv("./Datasets/uforeports.csv")
ufo.head()
# Out:
#    Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#               Time
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00
# 2  2/15/1931 14:00
# 3   6/1/1931 13:00
# 4  4/18/1933 19:00

# %%
ufo.drop(["Unnamed: 0","City"],axis=1,inplace=True)

# %%
ufo.head()
# Out:
#   Colors Reported Shape Reported State             Time
# 0             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1             NaN          OTHER    NJ  6/30/1930 20:00
# 2             NaN           OVAL    CO  2/15/1931 14:00
# 3             NaN           DISK    KS   6/1/1931 13:00
# 4             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# How to Delete row
ufo.drop([0,1],axis=0,inplace=True)

# %%
ufo.head()
# Out:
#   Colors Reported Shape Reported State             Time
# 2             NaN           OVAL    CO  2/15/1931 14:00
# 3             NaN           DISK    KS   6/1/1931 13:00
# 4             NaN          LIGHT    NY  4/18/1933 19:00
# 5             NaN           DISK    ND  9/15/1934 15:30
# 6             NaN         CIRCLE    CA   6/15/1935 0:00

# %% [markdown]
# # How do i sort pandas data frame or series ?

# %%
movies=pd.read_csv("./Datasets/imdbratings.csv")
movies.head()
# Out:
#    Unnamed: 0  star_rating                     title content_rating   genre  \
# 0           0          9.3  The Shawshank Redemption              R   Crime
# 1           1          9.2             The Godfather              R   Crime
# 2           2          9.1    The Godfather: Part II              R   Crime
# 3           3          9.0           The Dark Knight          PG-13  Action
# 4           4          8.9              Pulp Fiction              R   Crime
#
#    duration                                        actors_list
# 0       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title.sort_values()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
movies.title.sort_values(ascending=False)
# Out:
# 864                    [Rec]
# 526                     Zulu
# 615               Zombieland
# 677                   Zodiac
# 955         Zero Dark Thirty
#                ...
# 110    2001: A Space Odyssey
# 698                127 Hours
# 201         12 Years a Slave
# 5               12 Angry Men
# 542     (500) Days of Summer
# Name: title, Length: 979, dtype: object

# %%
movies.sort_values("title")
# Out:
#      Unnamed: 0  star_rating                  title content_rating      genre  \
# 542         542          7.8   (500) Days of Summer          PG-13     Comedy
# 5             5          8.9           12 Angry Men      NOT RATED      Drama
# 201         201          8.1       12 Years a Slave              R  Biography
# 698         698          7.6              127 Hours              R  Adventure
# 110         110          8.3  2001: A Space Odyssey              G    Mystery
# ..          ...          ...                    ...            ...        ...
# 955         955          7.4       Zero Dark Thirty              R      Drama
# 677         677          7.7                 Zodiac              R      Crime
# 615         615          7.7             Zombieland              R     Comedy
# 526         526          7.8                   Zulu        UNRATED      Drama
# 864         864          7.5                  [Rec]              R     Horror
#
# ...

# %%
movies.sort_values("duration",ascending=False)
# Out:
#      Unnamed: 0  star_rating                              title  \
# 476         476          7.8                             Hamlet
# 157         157          8.2                 Gone with the Wind
# 78           78          8.4        Once Upon a Time in America
# 142         142          8.3  Lagaan: Once Upon a Time in India
# 445         445          7.9               The Ten Commandments
# ..          ...          ...                                ...
# 293         293          8.1                          Duck Soup
# 88           88          8.4                            The Kid
# 258         258          8.1        The Cabinet of Dr. Caligari
# 338         338          8.0                Battleship Potemkin
# 389         389          8.0                             Freaks
#
#     content_rating      genre  duration  \
# 476          PG-13      Drama       242
# 157              G      Drama       238
# 78               R      Crime       229
# ...

# %%
movies.sort_values(["content_rating","duration"])
# Out:
#      Unnamed: 0  star_rating                               title  \
# 713         713          7.6                     The Jungle Book
# 513         513          7.8      Invasion of the Body Snatchers
# 272         272          8.1                         The Killing
# 703         703          7.6                             Dracula
# 612         612          7.7                  A Hard Day's Night
# ..          ...          ...                                 ...
# 387         387          8.0                     Midnight Cowboy
# 86           86          8.4                  A Clockwork Orange
# 187         187          8.2  Butch Cassidy and the Sundance Kid
# 936         936          7.4                           True Grit
# 649         649          7.7                   Where Eagles Dare
#
#     content_rating      genre  duration  \
# 713       APPROVED  Animation        78
# 513       APPROVED     Horror        80
# 272       APPROVED      Crime        85
# ...

# %% [markdown]
# # How do i filter rows in DataFrame by column values

# %%
movies.head()
# Out:
#    Unnamed: 0  star_rating                     title content_rating   genre  \
# 0           0          9.3  The Shawshank Redemption              R   Crime
# 1           1          9.2             The Godfather              R   Crime
# 2           2          9.1    The Godfather: Part II              R   Crime
# 3           3          9.0           The Dark Knight          PG-13  Action
# 4           4          8.9              Pulp Fiction              R   Crime
#
#    duration                                        actors_list
# 0       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
booleans=[]
for length in movies.duration:
    if length >= 200:
        booleans.append(True)
    else:
        booleans.append(False)

# %%
len(booleans)
# Out:
# 979

# %%
booleans[0:5]
# Out:
# [False, False, True, False, False]

# %%
is_long=pd.Series(booleans)

# %%
is_long.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
movies[is_long]
# is_long consists of true and false for movie greater than 200 or not
#  SO when you pass is_long it only returns movie greather than 200
# Out:
#      Unnamed: 0  star_rating                                          title  \
# 2             2          9.1                         The Godfather: Part II
# 7             7          8.9  The Lord of the Rings: The Return of the King
# 17           17          8.7                                  Seven Samurai
# 78           78          8.4                    Once Upon a Time in America
# 85           85          8.4                             Lawrence of Arabia
# 142         142          8.3              Lagaan: Once Upon a Time in India
# 157         157          8.2                             Gone with the Wind
# 204         204          8.1                                        Ben-Hur
# 445         445          7.9                           The Ten Commandments
# 476         476          7.8                                         Hamlet
# 630         630          7.7                                      Malcolm X
# ...

# %%
is_long=movies.duration >= 200
movies[is_long].head()
# Out:
#     Unnamed: 0  star_rating                                          title  \
# 2            2          9.1                         The Godfather: Part II
# 7            7          8.9  The Lord of the Rings: The Return of the King
# 17          17          8.7                                  Seven Samurai
# 78          78          8.4                    Once Upon a Time in America
# 85          85          8.4                             Lawrence of Arabia
#
#    content_rating      genre  duration  \
# 2               R      Crime       200
# 7           PG-13  Adventure       201
# 17        UNRATED      Drama       207
# 78              R      Crime       229
# 85             PG  Adventure       216
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7   [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...
# ...

# %%
movies[movies["duration"] >= 200 ]["genre"]
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
movies[movies["duration"] >= 200 ]
# This is also Okay But its not the good practice to filter instead you have to use .loc
# Out:
#      Unnamed: 0  star_rating                                          title  \
# 2             2          9.1                         The Godfather: Part II
# 7             7          8.9  The Lord of the Rings: The Return of the King
# 17           17          8.7                                  Seven Samurai
# 78           78          8.4                    Once Upon a Time in America
# 85           85          8.4                             Lawrence of Arabia
# 142         142          8.3              Lagaan: Once Upon a Time in India
# 157         157          8.2                             Gone with the Wind
# 204         204          8.1                                        Ben-Hur
# 445         445          7.9                           The Ten Commandments
# 476         476          7.8                                         Hamlet
# 630         630          7.7                                      Malcolm X
# ...

# %%
movies.loc[movies["duration"] >= 200 ]
# Out:
#      Unnamed: 0  star_rating                                          title  \
# 2             2          9.1                         The Godfather: Part II
# 7             7          8.9  The Lord of the Rings: The Return of the King
# 17           17          8.7                                  Seven Samurai
# 78           78          8.4                    Once Upon a Time in America
# 85           85          8.4                             Lawrence of Arabia
# 142         142          8.3              Lagaan: Once Upon a Time in India
# 157         157          8.2                             Gone with the Wind
# 204         204          8.1                                        Ben-Hur
# 445         445          7.9                           The Ten Commandments
# 476         476          7.8                                         Hamlet
# 630         630          7.7                                      Malcolm X
# ...

# %% [markdown]
# # Multiple filter criteria

# %%
movies.head()
# Out:
#    Unnamed: 0  star_rating                     title content_rating   genre  \
# 0           0          9.3  The Shawshank Redemption              R   Crime
# 1           1          9.2             The Godfather              R   Crime
# 2           2          9.1    The Godfather: Part II              R   Crime
# 3           3          9.0           The Dark Knight          PG-13  Action
# 4           4          8.9              Pulp Fiction              R   Crime
#
#    duration                                        actors_list
# 0       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.loc[(movies.duration > 200) & (movies.genre=="Drama")]
# Out:
#      Unnamed: 0  star_rating               title content_rating  genre  \
# 17           17          8.7       Seven Samurai        UNRATED  Drama
# 157         157          8.2  Gone with the Wind              G  Drama
# 476         476          7.8              Hamlet          PG-13  Drama
#
#      duration                                        actors_list
# 17        207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
movies.loc[(movies.duration > 200) | (movies.genre=="Drama")]
# Out:
#      Unnamed: 0  star_rating                                          title  \
# 5             5          8.9                                   12 Angry Men
# 7             7          8.9  The Lord of the Rings: The Return of the King
# 9             9          8.9                                     Fight Club
# 13           13          8.8                                   Forrest Gump
# 16           16          8.7                One Flew Over the Cuckoo's Nest
# ..          ...          ...                                            ...
# 958         958          7.4                             My Sister's Keeper
# 968         968          7.4                            The English Patient
# 970         970          7.4                                    Wonder Boys
# 972         972          7.4                                 Blue Valentine
# 973         973          7.4                          The Cider House Rules
#
#     content_rating      genre  duration  \
# ...

# %%
ufo5=pd.read_csv("./Datasets/uforeports.csv",usecols=["City","State"])
# You can give names or index of columns
ufo5.head()
# Out:
#                    City State
# 0                Ithaca    NY
# 1           Willingboro    NJ
# 2               Holyoke    CO
# 3               Abilene    KS
# 4  New York Worlds Fair    NY

# %%
ufo5=pd.read_csv("./Datasets/uforeports.csv",nrows=3)
ufo5.head()
# Out:
#    Unnamed: 0         City  Colors Reported Shape Reported State  \
# 0           0       Ithaca              NaN       TRIANGLE    NY
# 1           1  Willingboro              NaN          OTHER    NJ
# 2           2      Holyoke              NaN           OVAL    CO
#
#               Time
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00
# 2  2/15/1931 14:00

# %%
# selectdtype feature
# include feature of describe() method of dataFrame

# %% [markdown]
# # How do I use axis parameter in pandas?

# %%
import pandas as pd
# drinks=pd.read_csv("http://bit.ly/drinksbycountry")
# drinks.to_csv("./Datasets/drinksbycountry.csv")

# %%
drinks=pd.read_csv("./Datasets/drinksbycountry.csv")
drinks.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
# 2           2      Algeria             25                0             14
# 3           3      Andorra            245              138            312
# 4           4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.drop("continent",axis=1).head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
# 2           2      Algeria             25                0             14
# 3           3      Andorra            245              138            312
# 4           4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
drinks.drop(2,axis=0).head()
# Out:
#    Unnamed: 0            country  beer_servings  spirit_servings  \
# 0           0        Afghanistan              0                0
# 1           1            Albania             89              132
# 3           3            Andorra            245              138
# 4           4             Angola            217               57
# 5           5  Antigua & Barbuda            102              128
#
#    wine_servings  total_litres_of_pure_alcohol      continent
# 0              0                           0.0           Asia
# 1             54                           4.9         Europe
# 3            312                          12.4         Europe
# 4             45                           5.9         Africa
# 5             45                           4.9  North America

# %%
drinks.mean(axis=1)
# Out:
# 0        0.00
# 1       56.18
# 2        8.34
# 3      142.08
# 4       65.78
#         ...
# 188    126.34
# 189     61.00
# 190     39.22
# 191     49.70
# 192     56.54
# Length: 193, dtype: float64

# %%
drinks.mean(axis="columns")
# Out:
# 0        0.00
# 1       56.18
# 2        8.34
# 3      142.08
# 4       65.78
#         ...
# 188    126.34
# 189     61.00
# 190     39.22
# 191     49.70
# 192     56.54
# Length: 193, dtype: float64

# %%
drinks.mean(axis="rows")
# Out:
# Unnamed: 0                       96.000000
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis=0)
# Out:
# Unnamed: 0                       96.000000
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %% [markdown]
# # How to use string methods in python?

# %%
"hello".upper()
# Out:
# 'HELLO'

# %%
orders=pd.read_table("http://bit.ly/chiporders")
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
order=pd.read_csv("./Datasets/Chiporders.csv",index_col=False)
order.head()
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
order[order.item_name.str.contains("Chicken")].head()
# Out:
#     Unnamed: 0  order_id  quantity             item_name  \
# 4            4         2         2          Chicken Bowl
# 5            5         3         1          Chicken Bowl
# 11          11         6         1  Chicken Crispy Tacos
# 12          12         6         1    Chicken Soft Tacos
# 13          13         7         1          Chicken Bowl
#
#                                    choice_description item_price
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 11  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12  [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# 13  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25

# %%
order.choice_description.str.replace("[","").str.replace("]","")
# Out:
# <ipython-input-246-2f2825b432cc>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   order.choice_description.str.replace("[","").str.replace("]","")
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
#                               ...
# 4617    Fresh Tomato Salsa, Rice, Black Beans, Sour Cr...
# 4618    Fresh Tomato Salsa, Rice, Sour Cream, Cheese, ...
# 4619    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# 4620       Fresh Tomato Salsa, Fajita Vegetables, Lettuce
# 4621    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# Name: choice_description, Length: 4622, dtype: object

# %%
order.choice_description.str.replace("[\[\]]","")
# Out:
# <ipython-input-247-899298d94a98>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   order.choice_description.str.replace("[\[\]]","")
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
#                               ...
# 4617    Fresh Tomato Salsa, Rice, Black Beans, Sour Cr...
# 4618    Fresh Tomato Salsa, Rice, Sour Cream, Cheese, ...
# 4619    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# 4620       Fresh Tomato Salsa, Fajita Vegetables, Lettuce
# 4621    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# Name: choice_description, Length: 4622, dtype: object

# %% [markdown]
# # How do I change the data type of a panda series

# %%
drinks.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
# 2           2      Algeria             25                0             14
# 3           3      Andorra            245              138            312
# 4           4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.dtypes
# Out:
# Unnamed: 0                        int64
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks["beer_servings"]=drinks.beer_servings.astype(float)

# %%
drinks.dtypes
# Out:
# Unnamed: 0                        int64
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# # 14 When to use a group by in pandas?

# %%
drinks=pd.read_csv("./Datasets/drinksbycountry.csv")
drinks.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
# 2           2      Algeria             25                0             14
# 3           3      Andorra            245              138            312
# 4           4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.groupby("continent").beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks[drinks.continent=="Africa"].beer_servings.mean()
# Out:
# 61.471698113207545

# %%
drinks.groupby("continent").beer_servings.agg(["count","min","max","mean"])
# Out:
#                count  min  max        mean
# continent
# Africa            53    0  376   61.471698
# Asia              44    0  247   37.045455
# Europe            45    0  361  193.777778
# North America     23    1  285  145.434783
# Oceania           16    0  306   89.687500
# South America     12   93  333  175.083333

# %%
drinks.groupby("continent").mean()
# Out:
#                Unnamed: 0  beer_servings  spirit_servings  wine_servings  \
# continent
# Africa          93.396226      61.471698        16.339623      16.264151
# Asia           109.000000      37.045455        60.840909       9.068182
# Europe          89.377778     193.777778       132.555556     142.222222
# North America   79.869565     145.434783       165.739130      24.521739
# Oceania        117.312500      89.687500        58.437500      35.625000
# South America   87.166667     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
# %matplotlib inline
drinks.groupby("continent").mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='continent'>

# %% [markdown]
# # 15 How to explore pandas series?

# %%
movies=pd.read_csv("./Datasets/imdbratings.csv")

# %%
movies.head()
# Out:
#    Unnamed: 0  star_rating                     title content_rating   genre  \
# 0           0          9.3  The Shawshank Redemption              R   Crime
# 1           1          9.2             The Godfather              R   Crime
# 2           2          9.1    The Godfather: Part II              R   Crime
# 3           3          9.0           The Dark Knight          PG-13  Action
# 4           4          8.9              Pulp Fiction              R   Crime
#
#    duration                                        actors_list
# 0       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.dtypes
# Out:
# Unnamed: 0          int64
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
movies.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
movies.genre.value_counts(normalize=True)
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Thriller     0.005107
# Sci-Fi       0.005107
# Film-Noir    0.003064
# Family       0.002043
# History      0.001021
# Fantasy      0.001021
# Name: genre, dtype: float64

# %%
type(movies.genre.value_counts(normalize=True))
# Out:
# pandas.core.series.Series

# %%
movies.duration.mean()
# Out:
# 120.97957099080695

# %%
movies.duration.value_counts()
# Out:
# 112    23
# 113    22
# 101    20
# 102    20
# 129    19
#        ..
# 180     1
# 182     1
# 183     1
# 184     1
# 242     1
# Name: duration, Length: 133, dtype: int64

# %%
# %matplotlib inline
movies.duration.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# %matplotlib inline
movies.duration.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 16 How to handle missing values?

# %%
import pandas as pd

# %%
ufo=pd.read_csv("./Datasets/uforeports.csv")

# %%
ufo.head()
# Out:
#    Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#               Time
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00
# 2  2/15/1931 14:00
# 3   6/1/1931 13:00
# 4  4/18/1933 19:00

# %%
ufo.isnull()
# Out:
#        Unnamed: 0   City  Colors Reported  Shape Reported  State   Time
# 0           False  False             True           False  False  False
# 1           False  False             True           False  False  False
# 2           False  False             True           False  False  False
# 3           False  False             True           False  False  False
# 4           False  False             True           False  False  False
# ...           ...    ...              ...             ...    ...    ...
# 18236       False  False             True           False  False  False
# 18237       False  False             True           False  False  False
# 18238       False  False             True            True  False  False
# 18239       False  False            False           False  False  False
# 18240       False  False             True           False  False  False
#
# [18241 rows x 6 columns]

# %%
ufo.isnull().sum()
# Out:
# Unnamed: 0             0
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo[ufo["City"].isnull()]
# Get the list of the null values in City column
# Out:
#        Unnamed: 0 City Colors Reported Shape Reported State              Time
# 21             21  NaN             NaN            NaN    LA    8/15/1943 0:00
# 22             22  NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204           204  NaN             NaN           DISK    CA   7/15/1952 12:30
# 241           241  NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613           613  NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877         1877  NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013         2013  NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546         2546  NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123         3123  NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736         4736  NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269         5269  NaN             NaN            NaN    AZ   6/30/1985 21:30
# ...

# %%
ufo.shape
# Out:
# (18241, 6)

# %%
ufo.dropna(how="any").shape
# Out:
# (2486, 6)

# %%
ufo.dropna(how="all").shape
# Out:
# (18241, 6)

# %%
ufo.dropna(subset=["City","Shape Reported"],how="all").shape
# Out:
# (18237, 6)

# %%
ufo.dropna(subset=["City","Shape Reported"],how="all").shape
# Out:
# (18237, 6)

# %%
ufo["Shape Reported"].value_counts(dropna=False)
# Out:
# LIGHT        2803
# NaN          2644
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# PYRAMID         1
# FLARE           1
# DOME            1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
# Adding Nan in shape to various category
ufo["Shape Reported"].fillna(value="VARIOUS",inplace=True)

# %%
ufo["Shape Reported"].value_counts()
# Out:
# VARIOUS      2977
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# PYRAMID         1
# HEXAGON         1
# DOME            1
# FLARE           1
# Name: Shape Reported, dtype: int64

# %% [markdown]
# # What do i need to know about the pandas index? Part 1

# %%
drinks=pd.read_csv("./Datasets/drinksbycountry.csv")

# %%
drinks.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
# 2           2      Algeria             25                0             14
# 3           3      Andorra            245              138            312
# 4           4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.columns
# Out:
# Index(['Unnamed: 0', 'country', 'beer_servings', 'spirit_servings',
#        'wine_servings', 'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.shape
# Out:
# (193, 7)

# %%
drinks[drinks.continent=="South America"]
# index is used for identification even though the data set is used for filteration
# Out:
#      Unnamed: 0    country  beer_servings  spirit_servings  wine_servings  \
# 6             6  Argentina            193               25            221
# 20           20    Bolivia            167               41              8
# 23           23     Brazil            245              145             16
# 35           35      Chile            130              124            172
# 37           37   Colombia            159               76              3
# 52           52    Ecuador            162               74              3
# 72           72     Guyana             93              302              1
# 132         132   Paraguay            213              117             74
# 133         133       Peru            163              160             21
# 163         163   Suriname            128              178              7
# 185         185    Uruguay            115               35            220
# 188         188  Venezuela            333              100              3
#
# ...

# %%
drinks.loc[23,"beer_servings"]
# Out:
# 245

# %%
drinks.set_index("country",inplace=True)

# %%
drinks
# Out:
#              Unnamed: 0  beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan           0              0                0              0
# Albania               1             89              132             54
# Algeria               2             25                0             14
# Andorra               3            245              138            312
# Angola                4            217               57             45
# ...                 ...            ...              ...            ...
# Venezuela           188            333              100              3
# Vietnam             189            111                2              1
# Yemen               190              6                0              0
# Zambia              191             32               19              4
# Zimbabwe            192             64               18              4
#
#              total_litres_of_pure_alcohol      continent
# country
# ...

# %%
drinks.set_index("wine_servings")
# Out:
#                Unnamed: 0      country  beer_servings  spirit_servings  \
# wine_servings
# 0                       0  Afghanistan              0                0
# 54                      1      Albania             89              132
# 14                      2      Algeria             25                0
# 312                     3      Andorra            245              138
# 45                      4       Angola            217               57
# ...                   ...          ...            ...              ...
# 3                     188    Venezuela            333              100
# 1                     189      Vietnam            111                2
# 0                     190        Yemen              6                0
# 4                     191       Zambia             32               19
# 4                     192     Zimbabwe             64               18
#
#                total_litres_of_pure_alcohol      continent
# wine_servings
# ...

# %%
drinks.loc["Brazil","beer_servings"]
# Out:
# 245

# %%
# At the top you use to see the name for index the below code is to remove the name
drinks.index.name=None
drinks.head()
# Out:
#              Unnamed: 0  beer_servings  spirit_servings  wine_servings  \
# Afghanistan           0              0                0              0
# Albania               1             89              132             54
# Algeria               2             25                0             14
# Andorra               3            245              138            312
# Angola                4            217               57             45
#
#              total_litres_of_pure_alcohol continent
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
# adding index name and reseting the index
drinks.index.name="country"
drinks.head()
# Out:
#              Unnamed: 0  beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan           0              0                0              0
# Albania               1             89              132             54
# Algeria               2             25                0             14
# Andorra               3            245              138            312
# Angola                4            217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
# Resetting the name of the index
drinks.reset_index(inplace=True)
drinks.head()
# Out:
#    index      country  Unnamed: 0  beer_servings  spirit_servings  \
# 0      0  Afghanistan           0              0                0
# 1      1      Albania           1             89              132
# 2      2      Algeria           2             25                0
# 3      3      Andorra           3            245              138
# 4      4       Angola           4            217               57
#
#    wine_servings  total_litres_of_pure_alcohol continent
# 0              0                           0.0      Asia
# 1             54                           4.9    Europe
# 2             14                           0.7    Africa
# 3            312                          12.4    Europe
# 4             45                           5.9    Africa

# %% [markdown]
# # What do I need to know about the index ? Part 2
#
#  Today we will talk about series index and alignment

# %%
drinks=pd.read_csv("./Datasets/drinksbycountry.csv")

# %%
drinks.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
# 2           2      Algeria             25                0             14
# 3           3      Andorra            245              138            312
# 4           4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.continent.head()
# Out:
# 0      Asia
# 1    Europe
# 2    Africa
# 3    Europe
# 4    Africa
# Name: continent, dtype: object

# %%
drinks.set_index("country",inplace=True)

# %%
drinks.head()
# Out:
#              Unnamed: 0  beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan           0              0                0              0
# Albania               1             89              132             54
# Algeria               2             25                0             14
# Andorra               3            245              138            312
# Angola                4            217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.continent.head()
# Out:
# country
# Afghanistan      Asia
# Albania        Europe
# Algeria        Africa
# Andorra        Europe
# Angola         Africa
# Name: continent, dtype: object

# %%
drinks.continent.value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
drinks.continent.value_counts().values
# Out:
# array([53, 45, 44, 23, 16, 12], dtype=int64)

# %%
drinks.continent.value_counts().index
# Out:
# Index(['Africa', 'Europe', 'Asia', 'North America', 'Oceania',
#        'South America'],
#       dtype='object')

# %%
# SO these series will have both index and values so that you can access the values using index
drinks.continent.value_counts()["Africa"]
# Out:
# 53

# %%
# Sorting
# You can use both sorting technique sorting index or values
drinks.continent.value_counts().sort_index()
# Out:
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
drinks.continent.value_counts().sort_index()
# Out:
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
people=pd.Series([30000,85000],index=["Albania","Andorra"],name="Population")

# %%
people
# Out:
# Albania    30000
# Andorra    85000
# Name: Population, dtype: int64

# %%
drinks.beer_servings* people
# Out:
# Afghanistan           NaN
# Albania         2670000.0
# Algeria               NaN
# Andorra        20825000.0
# Angola                NaN
#                   ...
# Venezuela             NaN
# Vietnam               NaN
# Yemen                 NaN
# Zambia                NaN
# Zimbabwe              NaN
# Length: 193, dtype: float64

# %%
pd.concat([drinks,people],axis=1).head()
# Even though it dint have the complete data it put the data in the right spots because of the  SERIES INDEXING
# Out:
#              Unnamed: 0  beer_servings  spirit_servings  wine_servings  \
# Afghanistan           0              0                0              0
# Albania               1             89              132             54
# Algeria               2             25                0             14
# Andorra               3            245              138            312
# Angola                4            217               57             45
#
#              total_litres_of_pure_alcohol continent  Population
# Afghanistan                           0.0      Asia         NaN
# Albania                               4.9    Europe     30000.0
# Algeria                               0.7    Africa         NaN
# Andorra                              12.4    Europe     85000.0
# Angola                                5.9    Africa         NaN

# %% [markdown]
# # Pandas how to select multiple rows and columns from pandas Data frame
#
# youTUbe LInk
#
# https://www.youtube.com/watch?v=xvpNA7bC8cs&list=PL5-da3qGB5ICCsgW1MxlZ0Hq8LL5U3u9y&index=19

# %%
ufo=pd.read_csv("./Datasets/uforeports.csv")
ufo.head()
# Out:
#    Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#               Time
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00
# 2  2/15/1931 14:00
# 3   6/1/1931 13:00
# 4  4/18/1933 19:00

# %% [markdown]
# # When should I use the "inplace" parameter in pandas?

# %%
import pandas as pd
ufo=pd.read_csv("./Datasets/uforeports.csv")
ufo.head()
# Out:
#    Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#               Time
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00
# 2  2/15/1931 14:00
# 3   6/1/1931 13:00
# 4  4/18/1933 19:00

# %%
ufo.drop("City",axis=1).head()
ufo.head()
# Out:
#    Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#               Time
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00
# 2  2/15/1931 14:00
# 3   6/1/1931 13:00
# 4  4/18/1933 19:00

# %%
ufo.drop("City",axis=1,inplace=True)
ufo.head()
# Out:
#    Unnamed: 0 Colors Reported Shape Reported State             Time
# 0           0             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           1             NaN          OTHER    NJ  6/30/1930 20:00
# 2           2             NaN           OVAL    CO  2/15/1931 14:00
# 3           3             NaN           DISK    KS   6/1/1931 13:00
# 4           4             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# # How do i make my dataFrame faster and smaller?

# %%
drinks=pd.read_csv("./Datasets/drinksbycountry.csv")
drinks.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
# 2           2      Algeria             25                0             14
# 3           3      Andorra            245              138            312
# 4           4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa
