# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Loading data from Pandas

# %%
import pandas as  pd
df=pd.read_csv("./Datasets/Pokemon.csv")
df1=pd.read_excel("./Datasets/pokemon_data.xlsx")
df2=pd.read_csv("./Datasets/pokemon_data.txt",delimiter="\t" )
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df2
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
df.head(12)
# Out:
#     #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0   1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1   2                    Ivysaur  Grass  Poison    405  60      62       63
# 2   3                   Venusaur  Grass  Poison    525  80      82       83
# 3   3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4   4                 Charmander   Fire     NaN    309  39      52       43
# 5   5                 Charmeleon   Fire     NaN    405  58      64       58
# 6   6                  Charizard   Fire  Flying    534  78      84       78
# 7   6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8   6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9   7                   Squirtle  Water     NaN    314  44      48       65
# 10  8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %%
df.tail()
# Even things like df.tail(1) or df.tial(16) works well
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df.columns[1:]
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df["Name"][0:15])
# Out:
# 0                     Bulbasaur
# 1                       Ivysaur
# 2                      Venusaur
# 3         VenusaurMega Venusaur
# 4                    Charmander
# 5                    Charmeleon
# 6                     Charizard
# 7     CharizardMega Charizard X
# 8     CharizardMega Charizard Y
# 9                      Squirtle
# 10                    Wartortle
# 11                    Blastoise
# 12      BlastoiseMega Blastoise
# 13                     Caterpie
# 14                      Metapod
# Name: Name, dtype: object

# %%
df.Name[:20]
# Out:
# 0                     Bulbasaur
# 1                       Ivysaur
# 2                      Venusaur
# 3         VenusaurMega Venusaur
# 4                    Charmander
# 5                    Charmeleon
# 6                     Charizard
# 7     CharizardMega Charizard X
# 8     CharizardMega Charizard Y
# 9                      Squirtle
# 10                    Wartortle
# 11                    Blastoise
# 12      BlastoiseMega Blastoise
# 13                     Caterpie
# 14                      Metapod
# 15                   Butterfree
# 16                       Weedle
# 17                       Kakuna
# 18                     Beedrill
# 19        BeedrillMega Beedrill
# Name: Name, dtype: object

# %%
df[["Name","Type 1"]]
# Out:
#                       Name   Type 1
# 0                Bulbasaur    Grass
# 1                  Ivysaur    Grass
# 2                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 795                Diancie     Rock
# 796    DiancieMega Diancie     Rock
# 797    HoopaHoopa Confined  Psychic
# 798     HoopaHoopa Unbound  Psychic
# 799              Volcanion     Fire
#
# [800 rows x 2 columns]

# %%
df.columns[1:]
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.iloc[:10]
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
# for index,row in df.iterrows():
#     print(index,row[["Name","Type 1"]])

# %%
df.loc[df["Type 1"]== "Grass"]
# Use Fire or grass
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    318   45      49       49
# 1      2                Ivysaur  Grass    Poison    405   60      62       63
# 2      3               Venusaur  Grass    Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    625   80     100      123
# 48    43                 Oddish  Grass    Poison    320   45      50       55
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN    313   56      61       65
# 719  651              Quilladin  Grass       NaN    405   61      78       95
# 720  652             Chesnaught  Grass  Fighting    530   88     107      122
# 740  672                 Skiddo  Grass       NaN    350   66      65       48
# 741  673                 Gogoat  Grass       NaN    531  123     100       62
#
# ...

# %%
df.loc[(df["Type 1"]=="Grass") | (df["Type 2"]== "Poison")]
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    318   45      49       49
# 1      2                Ivysaur  Grass    Poison    405   60      62       63
# 2      3               Venusaur  Grass    Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    625   80     100      123
# 16    13                 Weedle    Bug    Poison    195   40      35       30
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN    313   56      61       65
# 719  651              Quilladin  Grass       NaN    405   61      78       95
# 720  652             Chesnaught  Grass  Fighting    530   88     107      122
# 740  672                 Skiddo  Grass       NaN    350   66      65       48
# 741  673                 Gogoat  Grass       NaN    531  123     100       62
#
# ...

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.sort_values(["Name","Total"],ascending=True)
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making changes to the data

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df["Total"]=df["HP"]+df["Attack"]+df["Defense"]

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    143  45      49       49
# 1  2                Ivysaur  Grass  Poison    185  60      62       63
# 2  3               Venusaur  Grass  Poison    245  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    303  80     100      123
# 4  4             Charmander   Fire     NaN    134  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df["Total"]=df.iloc[:,4:9].sum()

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    NaN  45      49       49
# 1      2                Ivysaur    Grass  Poison    NaN  60      62       63
# 2      3               Venusaur    Grass  Poison    NaN  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    NaN  80     100      123
# 4      4             Charmander     Fire     NaN    NaN  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    NaN  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    NaN  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    NaN  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    NaN  80     160       60
# 799  721              Volcanion     Fire   Water    NaN  80     110      120
#
# ...

# %%
cols=list(df.columns.values)

# %%
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'Total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary']

# %% [markdown]
# # Saving our data

# %%
df2.to_csv("Modified1.csv",index=False)

# %%
df2
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # Series Object in Pandas

# %%
import pandas as pd
data=[1,2,3,4]
print(type(data))
series1=pd.Series(data)
print(series1,type(series1))
# Out:
# <class 'list'>
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
series1=pd.Series(data,index=["b","a","c","d"])
print(series1,type(series1))
# Out:
# b    1
# a    2
# c    3
# d    4
# dtype: int64 <class 'pandas.core.series.Series'>

# %% [markdown]
# # How to create a data frame

# %%
import pandas as pd

# %%
data=[1,2,3,4,5]
df=pd.DataFrame(data)

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
#  Creating a data frame using a dictionary
diction={"fruits":["apples","mangoes","bananas"],"count":[10,20,45]}
diction
df=pd.DataFrame(diction)



df
# Out:
#     fruits  count
# 0   apples     10
# 1  mangoes     20
# 2  bananas     45

# %%
df.fruits
# Out:
# 0     apples
# 1    mangoes
# 2    bananas
# Name: fruits, dtype: object

# %% [markdown]
# # How to perform merge operation

# %%
import pandas as pd
player=["player1","player2","Player3"]
point=[8,9,6]
title=["Game","Game1","Game3"]
df1=pd.DataFrame({"players":player,"points":point,"title":title})
df1
# Out:
#    players  points  title
# 0  player1       8   Game
# 1  player2       9  Game1
# 2  Player3       6  Game3

# %%
player=["player1","player5","player7"]
power=["Punch","Kick","Elbow"]
title=["Game1","Game5","Game6"]
df2=pd.DataFrame({"players":player,"power":power,"title":title})
df2
# Out:
#    players  power  title
# 0  player1  Punch  Game1
# 1  player5   Kick  Game5
# 2  player7  Elbow  Game6

# %%
# Inner merge
df1.merge(df2,on="title",how="inner")
# Out:
#   players_x  points  title players_y  power
# 0   player2       9  Game1   player1  Punch

# %%
df1.merge(df2,on="players",how="inner")
# Out:
#    players  points title_x  power title_y
# 0  player1       8    Game  Punch   Game1

# %%
# Left merge
df1.merge(df2,on="players",how="left")
# Out:
#    players  points title_x  power title_y
# 0  player1       8    Game  Punch   Game1
# 1  player2       9   Game1    NaN     NaN
# 2  Player3       6   Game3    NaN     NaN

# %%
# right merge
df1.merge(df2,on="players",how="right")
# Out:
#    players  points title_x  power title_y
# 0  player1     8.0    Game  Punch   Game1
# 1  player5     NaN     NaN   Kick   Game5
# 2  player7     NaN     NaN  Elbow   Game6

# %%
# Outer merge
df1.merge(df2,on="players",how="outer")
# Out:
#    players  points title_x  power title_y
# 0  player1     8.0    Game  Punch   Game1
# 1  player2     9.0   Game1    NaN     NaN
# 2  Player3     6.0   Game3    NaN     NaN
# 3  player5     NaN     NaN   Kick   Game5
# 4  player7     NaN     NaN  Elbow   Game6

# %% [markdown]
# ## In merge the two data frame must have same column in common or else we wont be able to merge
# ## But in case of join there is the two data frame must have a complete different columns

# %% [markdown]
# # How to perform join operation in Pandas

# %%
player=["player1","player2","Player3"]
point=[8,9,6]
title=["Game","Game1","Game3"]
df3=pd.DataFrame({"players":player,"points":point,"title":title},index=["L1","L2","L3"])
df3
# Out:
#     players  points  title
# L1  player1       8   Game
# L2  player2       9  Game1
# L3  Player3       6  Game3

# %%
player=["Player1","player2",'player3']
power=["kick","Punch","Elbow"]
game=['Game','Game1','Game2']
df4=pd.DataFrame({"Player":player,"power":power,"games":game},index=["L2","L3","L4"])
df4
# Out:
#      Player  power  games
# L2  Player1   kick   Game
# L3  player2  Punch  Game1
# L4  player3  Elbow  Game2

# %%
df3.join(df4,how="inner")
# Out:
#     players  points  title   Player  power  games
# L2  player2       9  Game1  Player1   kick   Game
# L3  Player3       6  Game3  player2  Punch  Game1

# %%
df3.join(df4,how="left")
# Out:
#     players  points  title   Player  power  games
# L1  player1       8   Game      NaN    NaN    NaN
# L2  player2       9  Game1  Player1   kick   Game
# L3  Player3       6  Game3  player2  Punch  Game1

# %%
df3.join(df4,how="right")
# Out:
#     players  points  title   Player  power  games
# L2  player2     9.0  Game1  Player1   kick   Game
# L3  Player3     6.0  Game3  player2  Punch  Game1
# L4      NaN     NaN    NaN  player3  Elbow  Game2

# %%
df3.join(df4,how="outer")
# Out:
#     players  points  title   Player  power  games
# L1  player1     8.0   Game      NaN    NaN    NaN
# L2  player2     9.0  Game1  Player1   kick   Game
# L3  Player3     6.0  Game3  player2  Punch  Game1
# L4      NaN     NaN    NaN  player3  Elbow  Game2

# %% [markdown]
# # How to concatenate two data frames in pandas

# %%
pd.concat([df3,df4]).shape
# Out:
# (6, 6)

# %%
pd.concat([df3,df4])
# Out:
#     players  points  title   Player  power  games
# L1  player1     8.0   Game      NaN    NaN    NaN
# L2  player2     9.0  Game1      NaN    NaN    NaN
# L3  Player3     6.0  Game3      NaN    NaN    NaN
# L2      NaN     NaN    NaN  Player1   kick   Game
# L3      NaN     NaN    NaN  player2  Punch  Game1
# L4      NaN     NaN    NaN  player3  Elbow  Game2

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, L1 to L3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   players  3 non-null      object
#  1   points   3 non-null      int64
#  2   title    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df3.mean()
# Out:
# points    7.666667
# dtype: float64

# %%
import pandas as  pd
df=pd.read_csv("./Datasets/Pokemon.csv")
df1=pd.read_excel("./Datasets/pokemon_data.xlsx")
df2=pd.read_csv("./Datasets/pokemon_data.txt",delimiter="\t" )
df.abshead(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.iloc[:,4:].head()
# Out:
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0    318  45      49       49       65       65     45           1      False
# 1    405  60      62       63       80       80     60           1      False
# 2    525  80      82       83      100      100     80           1      False
# 3    625  80     100      123      122      120     80           1      False
# 4    309  39      52       43       60       50     65           1      False

# %%
df.loc[0:4,"Name":'Defense']
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense
# 0              Bulbasaur  Grass  Poison    318  45      49       49
# 1                Ivysaur  Grass  Poison    405  60      62       63
# 2               Venusaur  Grass  Poison    525  80      82       83
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4             Charmander   Fire     NaN    309  39      52       43

# %% [markdown]
# # Filtering Data

# %%
df.loc[(df["Type 1"]=="Grass") & (df["Type 2"]=="Poison") & (df["HP"]>70)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 652  591              Amoonguss  Grass  Poison    464  114      85       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 50       110       90     50           1      False
# 77       100       70     70           1      False
# 652       85       80     30           5      False

# %%
# THis returns the list of names which contains "Mega"
# In the .contains method you can pass the regex expressions
df.loc[df["Name"].str.contains("Mega")].head()
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 12   9    BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 19  15      BeedrillMega Beedrill    Bug  Poison    495  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3       122      120     80           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 12      135      115     78           1      False
# 19       15       80    145           1      False

# %%
# This list contains the row which names does not contain "Mega"
df.loc[~df["Name"].str.contains("Mega")].head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 4     65           1      False
# 5     80           1      False

# %%
import re
df.loc[df["Type 1"].str.contains('fire|grass',flags=re.I,regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
#  # Conditional changes

# %%
df.loc[df["Type 1"]=="Fire","Type 2"]="Milan"

# %%
df.loc[df["Type 2"]=="Milan"]
# Out:
#        #                       Name Type 1 Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire  Milan    309   39      52
# 5      5                 Charmeleon   Fire  Milan    405   58      64
# 6      6                  Charizard   Fire  Milan    534   78      84
# 7      6  CharizardMega Charizard X   Fire  Milan    634   78     130
# 8      6  CharizardMega Charizard Y   Fire  Milan    634   78     104
# 42    37                     Vulpix   Fire  Milan    299   38      41
# 43    38                  Ninetales   Fire  Milan    505   73      76
# 63    58                  Growlithe   Fire  Milan    350   55      70
# 64    59                   Arcanine   Fire  Milan    555   90     110
# 83    77                     Ponyta   Fire  Milan    410   50      85
# 84    78                   Rapidash   Fire  Milan    500   65     100
# 135  126                     Magmar   Fire  Milan    495   65      95
# ...

# %%
df.loc[df.Total > 500 ,["Generation","Legendary"]]=["Milan","Gowda"]

# %%
df.loc[(df.Generation=="Milan") & (df.Legendary == "Gowda")]
# Out:
#        #                       Name   Type 1  Type 2  Total  HP  Attack  \
# 2      3                   Venusaur    Grass  Poison    525  80      82
# 3      3      VenusaurMega Venusaur    Grass  Poison    625  80     100
# 6      6                  Charizard     Fire   Milan    534  78      84
# 7      6  CharizardMega Charizard X     Fire   Milan    634  78     130
# 8      6  CharizardMega Charizard Y     Fire   Milan    634  78     104
# ..   ...                        ...      ...     ...    ...  ..     ...
# 795  719                    Diancie     Rock   Fairy    600  50     100
# 796  719        DiancieMega Diancie     Rock   Fairy    700  50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799  721                  Volcanion     Fire   Milan    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed Generation Legendary
# ...

# %%
df.groupby(["Type 1"]).mean().sort_values("Attack",ascending=False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# ...

# %%
df.groupby(["Type 1","Type 2"]).count()["#"]
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: #, Length: 128, dtype: int64

# %% [markdown]
# # How to deal with large amount of data

# %%
# chunk size an argument in read csv
